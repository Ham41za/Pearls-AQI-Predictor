# %% [markdown]
# <a href="https://colab.research.google.com/github/Ham41za/Pearls-AQI-Predictor/blob/main/AQI_dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -o Pearls_AQI_HTML_Dashboard.zip
# Out:
# Archive:  Pearls_AQI_HTML_Dashboard.zip
#   inflating: pearls_html_dashboard/app.py
#   inflating: pearls_html_dashboard/templates/index.html
#   inflating: pearls_html_dashboard/static/style.css
#   inflating: pearls_html_dashboard/static/app.js
#   inflating: pearls_html_dashboard/README.txt

# %%
import os

print("Current directory:")
print(os.getcwd())

print("\nFiles:")
print(os.listdir())
# Out:
# Current directory:
# /content
#
# Files:
# ['.config', '.ipynb_checkpoints', 'pearls_html_dashboard', 'models', 'Pearls_AQI_HTML_Dashboard.zip', 'aqi_ml_ready.csv', 'sample_data']

# %%
# !pip install -q flask pandas numpy scikit-learn joblib

# %%
import os

print("Dataset:", os.path.exists("aqi_ml_ready.csv"))

print("24h model:", os.path.exists("models/random_forest_24h.pkl"))
print("48h model:", os.path.exists("models/random_forest_48h.pkl"))
print("72h model:", os.path.exists("models/random_forest_72h.pkl"))
# Out:
# Dataset: True
# 24h model: True
# 48h model: True
# 72h model: True

# %%
# !python pearls_html_dashboard/app.py
# Out:
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [06/Sep/2026 14:17:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Sep/2026 14:17:38] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Sep/2026 14:17:38] "GET /static/app.js HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Sep/2026 14:17:39] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [06/Sep/2026 14:17:39] "GET /api/dashboard HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Sep/2026 14:18:39] "GET /api/dashboard HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Sep/2026 14:19:41] "GET /api/dashboard HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Sep/2026 14:20:40] "GET /api/dashboard HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Sep/2026 14:21:40] "GET /api/dashboard HTTP/1.1" 200 -

# %%
from google.colab.output import eval_js

url = eval_js("google.colab.kernel.proxyPort(5000)")
print("YOUR DASHBOARD URL:")
print(url)
# Out:
# YOUR DASHBOARD URL:
# https://5000-m-s-kkb-ass1a1-1gr5sx9uamy5a-a.asia-southeast1-1.prod.colab.dev
